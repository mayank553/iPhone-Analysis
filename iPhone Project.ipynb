# %%
import pandas as pd
df = pd.read_csv('iphone.csv')
df
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
df.columns
# Out:
# Index(['Product Name', 'Product URL', 'Brand', 'Sale Price', 'Mrp',
#        'Number Of Ratings', 'Number Of Reviews', 'Upc', 'Star Rating', 'Ram'],
#       dtype='object')

# %%
#The column names have spaces . rename the column names to have underscore '_' instead of space (try to do in one go instead of specifying each column nam in rename method)

df.columns= df.columns.str.replace(' ', '_')
df.columns
# Out:
# Index(['Product_Name', 'Product_URL', 'Brand', 'Sale_Price', 'Mrp',
#        'Number_Of_Ratings', 'Number_Of_Reviews', 'Upc', 'Star_Rating', 'Ram',
#        'Discount_Percentage', 'Storage', 'Color'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product_Name       62 non-null     object
#  1   Product_URL        62 non-null     object
#  2   Brand              62 non-null     object
#  3   Sale_Price         62 non-null     int64
#  4   Mrp                62 non-null     int64
#  5   Number_Of_Ratings  62 non-null     int64
#  6   Number_Of_Reviews  62 non-null     int64
#  7   Upc                62 non-null     object
#  8   Star_Rating        59 non-null     float64
#  9   Ram                62 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 5.0+ KB

# %%
df.isna().sum()
# Out:
# Product_Name         0
# Product_URL          0
# Brand                0
# Sale_Price           0
# Mrp                  0
# Number_Of_Ratings    0
# Number_Of_Reviews    0
# Upc                  0
# Star_Rating          3
# Ram                  0
# dtype: int64

# %%
#star rating for some of the models is missing in the dataset. fill those missing values with the average rating all the models.

missing_ratings = df[df['Star_Rating'].isna()]
print(missing_ratings[['Product_Name', 'Star_Rating']])
# Out:
#                                   Product_Name  Star_Rating
# 3              APPLE iPhone 8 (Silver, 256 GB)          NaN
# 10              Apple iPhone XR (Black, 64 GB)          NaN
# 32  APPLE iPhone 12 Pro Max (Graphite, 128 GB)          NaN

# %%
df['Star_Rating'].isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# Name: Star_Rating, Length: 62, dtype: bool

# %%
df[df['Star_Rating'].isna()]
# Out:
#                                   Product_Name  \
# 3              APPLE iPhone 8 (Silver, 256 GB)
# 10              Apple iPhone XR (Black, 64 GB)
# 32  APPLE iPhone 12 Pro Max (Graphite, 128 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 10  https://www.flipkart.com/apple-iphone-xr-black...  Apple       39999
# 32  https://www.flipkart.com/apple-iphone-12-pro-m...  Apple      120900
#
#        Mrp  Number_Of_Ratings  Number_Of_Reviews               Upc  \
# 3    77000              11202                794  MOBEXRGVMZWUHCBA
# 10   47900              79512               6796  MOBF9Z7ZPHGV4GNH
# 32  129900                580                 45  MOBFWBYZFDGQSDWS
#
#     Star_Rating   Ram
# 3           NaN  2 GB
# 10          NaN  4 GB
# 32          NaN  6 GB

# %%
df['Star_Rating'] = df['Star_Rating'].fillna(df['Star_Rating'].mean())

# %%
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
#df['Star_Rating'] = df.groupby('Ram')['Star_Rating'].transform(lambda x: x.fillna(x.mean()))
df['Star_Rating'].dtype
# Out:
# dtype('float64')

# %%
# Now instead of filling missing values with avg rating of full dataset , fill with avg rating based on RAM. example :  if rating for a 2 gb phone is missing then take average of all other 2 gb phones rating and fill that value.
df['Star_Rating'] = df.groupby('Ram')['Star_Rating'].transform(lambda x: x.fillna(x.mean()))
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# create a new column in the dataframe "Discount_Percentage" based on MRP and sale value

df['Discount_Percentage'] = ((df['Mrp'] - df['Sale_Price']) / df['Mrp']) * 100
df
# Out:
#                                 Product_Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
# which model has highest percent discount ?

df = df.sort_values(by='Discount_Percentage', ascending=False)
df
# Out:
#                                    Product_Name  \
# 18  APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 57               APPLE iPhone SE (Black, 64 GB)
# 52               APPLE iPhone SE (White, 64 GB)
# 53              APPLE iPhone SE (Black, 128 GB)
# 54              APPLE iPhone SE (White, 128 GB)
# ..                                          ...
# 2          APPLE iPhone 8 Plus (Silver, 256 GB)
# 1      APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 7           APPLE iPhone 8 (Space Grey, 256 GB)
# 6       APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 0             APPLE iPhone 8 Plus (Gold, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 18  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple       74999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# ...

# %%
max_discount_model = df.loc[df['Discount_Percentage'].idxmax(), 'Product_Name']
max_discount_value = df['Discount_Percentage'].max()
max_discount_model
# Out:
# 'APPLE iPhone 11 Pro (Midnight Green, 64 GB)'

# %%
# find total no of models each space configuration (128 GB , 64 GB etc)

df['Storage'] = df['Product_Name'].str.extract(r'(\d+\s*GB)')
storage_counts = df['Storage'].value_counts()
print(storage_counts)
# Out:
# Storage
# 128 GB    24
# 64 GB     20
# 256 GB    14
# 512 GB     4
# Name: count, dtype: int64

# %%
# find total number of models for each color 
import re

# Function to extract color from product name
def extract_color(product_name):
    match = re.search(r"\(([^,]+),", product_name)  # Captures everything before the comma
    return match.group(1).strip() if match else None  # Remove extra spaces if any

# Apply function to create a new column 'Color'
df['Color'] = df['Product_Name'].apply(extract_color)

# Display the updated DataFrame
print(df[['Product_Name', 'Color']].head())
# Out:
#                                    Product_Name           Color
# 18  APPLE iPhone 11 Pro (Midnight Green, 64 GB)  Midnight Green
# 57               APPLE iPhone SE (Black, 64 GB)           Black
# 52               APPLE iPhone SE (White, 64 GB)           White
# 53              APPLE iPhone SE (Black, 128 GB)           Black
# 54              APPLE iPhone SE (White, 128 GB)           White

# %%
df
# Out:
#                                    Product_Name  \
# 18  APPLE iPhone 11 Pro (Midnight Green, 64 GB)
# 57               APPLE iPhone SE (Black, 64 GB)
# 52               APPLE iPhone SE (White, 64 GB)
# 53              APPLE iPhone SE (Black, 128 GB)
# 54              APPLE iPhone SE (White, 128 GB)
# ..                                          ...
# 2          APPLE iPhone 8 Plus (Silver, 256 GB)
# 1      APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 7           APPLE iPhone 8 (Space Grey, 256 GB)
# 6       APPLE iPhone 8 Plus (Space Grey, 64 GB)
# 0             APPLE iPhone 8 Plus (Gold, 64 GB)
#
#                                           Product_URL  Brand  Sale_Price  \
# 18  https://www.flipkart.com/apple-iphone-11-pro-m...  Apple       74999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# ...

# %%
#find total number of models for each color 
color_counts = df['Color'].value_counts()
print(color_counts)
# Out:
# Color
# Black             10
# White             10
# Silver             7
# Space Grey         6
# Gold               6
# Red                5
# Pacific Blue       4
# Graphite           4
# Midnight Green     4
# Blue               2
# RED                1
# Coral              1
# Green              1
# Purple             1
# Name: count, dtype: int64

# %%
# list top 5 models having highest no of reviews 
df = df.sort_values(by='Number_Of_Reviews', ascending=False)
#df.head(5)
df[['Product_Name', 'Number_Of_Reviews']].head(5)
# Out:
#                        Product_Name  Number_Of_Reviews
# 57   APPLE iPhone SE (Black, 64 GB)               8161
# 53  APPLE iPhone SE (Black, 128 GB)               8161
# 55    APPLE iPhone SE (Red, 128 GB)               8161
# 23  Apple iPhone SE (White, 256 GB)               8161
# 54  APPLE iPhone SE (White, 128 GB)               8154

# %%
# price diffrence between highest price and lowest price iphone (based on mrp)
price_difference = df['Mrp'].max() - df['Mrp'].min()
print("Price Difference:", price_difference)
# Out:
# Price Difference: 110000

# %%
# find total no of reviews for iphone 11 and iphone 12 category . Output should have only 2 rows (for 11 and 12).

# Filter the DataFrame for iPhone 11 and iPhone 12 categories
iphone_11_reviews = df[df['Product_Name'].str.contains('iPhone 11', case=False)]
iphone_12_reviews = df[df['Product_Name'].str.contains('iPhone 12', case=False)]

# Calculate the total number of reviews for each category
total_reviews_11 = iphone_11_reviews['Number_Of_Reviews'].sum()
total_reviews_12 = iphone_12_reviews['Number_Of_Reviews'].sum()

# Create a new DataFrame with the results
result_df = pd.DataFrame({
    'iPhone Category': ['iPhone 11', 'iPhone 12'],
    'Total Reviews': [total_reviews_11, total_reviews_12]
})

# %%
result_df
# Out:
#   iPhone Category  Total Reviews
# 0       iPhone 11          25965
# 1       iPhone 12           2208

# %%
# which iphone has 3rd highest MRP
df_sorted = df.sort_values(by='Mrp', ascending=False)

third_highest_iphone = df_sorted.iloc[2]  

print(third_highest_iphone[['Product_Name', 'Mrp']])
# Out:
# Product_Name    APPLE iPhone 11 Pro (Space Grey, 512 GB)
# Mrp                                               140300
# Name: 19, dtype: object

# %%
# what is the average mrp of iphones which costs above 100,000
high_price_iphones = df[df['Mrp'] > 100000]

average_mrp = high_price_iphones['Mrp'].mean()

print(f"Average MRP of iPhones above ₹100,000: ₹{average_mrp:.2f}")
# Out:
# Average MRP of iPhones above ₹100,000: ₹130559.09

# %%
# which iphone with 128 GB space has highest ratings to review ratio
# Filter the DataFrame to include only iPhones with 128 GB of space
#df['Storage'] = df['Storage'].str.extract(r'(\d+)').astype(int)


df['Storage'] = df['Storage'].astype(str).str.extract(r'(\d+)').astype(float)
iphone_128gb = df[df['Storage'] == 128]

iphone_128gb

iphone_128gb['Ratings to Reviews Ratio'] = iphone_128gb['Number_Of_Ratings'] / iphone_128gb['Number_Of_Reviews']
iphone_128gb['Ratings to Reviews Ratio']

highest_ratio_iphone = iphone_128gb.loc[iphone_128gb['Ratings to Reviews Ratio'].idxmax()]
highest_ratio_iphone
# Out:
# C:\Users\MSII\AppData\Local\Temp\ipykernel_17992\1230756763.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iphone_128gb['Ratings to Reviews Ratio'] = iphone_128gb['Number_Of_Ratings'] / iphone_128gb['Number_Of_Reviews']
# Product_Name                                  APPLE iPhone 11 (Black, 128 GB)
# Product_URL                 https://www.flipkart.com/apple-iphone-11-black...
# Brand                                                                   Apple
# Sale_Price                                                              54999
# Mrp                                                                     59900
# Number_Of_Ratings                                                       43470
# ...
